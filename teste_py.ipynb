# %% [markdown]
# <a href="https://colab.research.google.com/github/fabio-sv/CodeC/blob/master/teste_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
valor =  10;

print(valor);
# Out:
# 10

# %% [markdown]
# teste colab
